# %%
from polarda import plot
import numpy as np
import matplotlib.pyplot as plt

# %%
random_groups = np.random.random((3, 100))
color = np.random.random(100)
sizes = np.random.random(100)*100

labels = ["Group 1", "Group 2", "Group 3"]

polar = plot.PolarPlot(fig = None, ax = None, values = random_groups, colors=color, size=sizes, labels = labels, label_offset = .1).plot()

plt.tight_layout()
plt.savefig("demo.png", bbox_inches="tight")
# Out:
# /var/folders/64/ytcycnwx6w936vfxs5_7q3hm0000gn/T/ipykernel_11109/71800402.py:9: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
